# %% [markdown]
# <a href="https://colab.research.google.com/github/pachterlab/rhopca/blob/main/functional_rhoPCA_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q scikit-fda==0.10.1
# !pip install git+https://github.com/pachterlab/rhopca.git
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 88.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 6.5 MB/s eta 0:00:00
# Collecting git+https://github.com/pachterlab/rhopca.git
#   Cloning https://github.com/pachterlab/rhopca.git to /tmp/pip-req-build-km1ohdqb
#   Running command git clone --filter=blob:none --quiet https://github.com/pachterlab/rhopca.git /tmp/pip-req-build-km1ohdqb
#   Resolved https://github.com/pachterlab/rhopca.git to commit 7618735fc4b1ad9b336da18857ec0673a4bcda77
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from rhopca==1.0.0) (2.0.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.12/dist-packages (from rhopca==1.0.0) (1.16.3)
# Requirement already satisfied: matplotlib>=3.7 in /usr/local/lib/python3.12/dist-packages (from rhopca==1.0.0) (3.10.0)
# Requirement already satisfied: seaborn>=0.12 in /usr/local/lib/python3.12/dist-packages (from rhopca==1.0.0) (0.13.2)
# Collecting anndata>=0.9 (from rhopca==1.0.0)
#   Downloading anndata-0.12.10-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.12/dist-packages (from rhopca==1.0.0) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.12/dist-packages (from rhopca==1.0.0) (1.6.1)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from rhopca==1.0.0) (2.2.2)
# Requirement already satisfied: scikit-fda>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from rhopca==1.0.0) (0.10.1)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.9->rhopca==1.0.0) (1.14.0)
# Requirement already satisfied: h5py>=3.8 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.9->rhopca==1.0.0) (3.16.0)
# Collecting legacy-api-wrap (from anndata>=0.9->rhopca==1.0.0)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata>=0.9->rhopca==1.0.0) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.9->rhopca==1.0.0) (26.0)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.9->rhopca==1.0.0)
#   Downloading zarr-3.1.6-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->rhopca==1.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->rhopca==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->rhopca==1.0.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->rhopca==1.0.0) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->rhopca==1.0.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->rhopca==1.0.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->rhopca==1.0.0) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.56->rhopca==1.0.0) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->rhopca==1.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->rhopca==1.0.0) (2025.3)
# Requirement already satisfied: dcor in /usr/local/lib/python3.12/dist-packages (from scikit-fda>=0.10.1->rhopca==1.0.0) (0.7)
# Requirement already satisfied: fdasrsf!=2.5.7,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-fda>=0.10.1->rhopca==1.0.0) (2.6.9)
# Requirement already satisfied: findiff in /usr/local/lib/python3.12/dist-packages (from scikit-fda>=0.10.1->rhopca==1.0.0) (0.13.1)
# Requirement already satisfied: lazy_loader in /usr/local/lib/python3.12/dist-packages (from scikit-fda>=0.10.1->rhopca==1.0.0) (0.5)
# Requirement already satisfied: multimethod!=1.11,!=1.11.1,>=1.5 in /usr/local/lib/python3.12/dist-packages (from scikit-fda>=0.10.1->rhopca==1.0.0) (2.0.2)
# Requirement already satisfied: rdata in /usr/local/lib/python3.12/dist-packages (from scikit-fda>=0.10.1->rhopca==1.0.0) (1.0.0)
# Requirement already satisfied: scikit-datasets>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from scikit-datasets[cran]>=0.2.2->scikit-fda>=0.10.1->rhopca==1.0.0) (0.2.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scikit-fda>=0.10.1->rhopca==1.0.0) (4.15.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->rhopca==1.0.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->rhopca==1.0.0) (3.6.0)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from fdasrsf!=2.5.7,>=2.2.0->scikit-fda>=0.10.1->rhopca==1.0.0) (3.0.12)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from fdasrsf!=2.5.7,>=2.2.0->scikit-fda>=0.10.1->rhopca==1.0.0) (1.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from fdasrsf!=2.5.7,>=2.2.0->scikit-fda>=0.10.1->rhopca==1.0.0) (4.67.3)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from fdasrsf!=2.5.7,>=2.2.0->scikit-fda>=0.10.1->rhopca==1.0.0) (1.17.0)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from fdasrsf!=2.5.7,>=2.2.0->scikit-fda>=0.10.1->rhopca==1.0.0) (2.0.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.9->rhopca==1.0.0)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.9->rhopca==1.0.0) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata>=0.9->rhopca==1.0.0)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from findiff->scikit-fda>=0.10.1->rhopca==1.0.0) (1.14.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from rdata->scikit-fda>=0.10.1->rhopca==1.0.0) (2025.12.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.0->fdasrsf!=2.5.7,>=2.2.0->scikit-fda>=0.10.1->rhopca==1.0.0) (3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.9->rhopca==1.0.0) (6.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->findiff->scikit-fda>=0.10.1->rhopca==1.0.0) (1.3.0)
# Downloading anndata-0.12.10-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.6/176.6 kB 5.4 MB/s eta 0:00:00
# Downloading zarr-3.1.6-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.7/295.7 kB 16.4 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 84.7 MB/s eta 0:00:00
# Building wheels for collected packages: rhopca
#   Building wheel for rhopca (pyproject.toml) ... done
#   Created wheel for rhopca: filename=rhopca-1.0.0-py3-none-any.whl size=23701 sha256=b5937af21ee1403abb54035c6b76b83b453420f9b299bf90a8d4f9e86cde9eae
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oojdcfzd/wheels/7a/8f/09/f543c48a25906406c7e346065324db52377f3861f96fddefbd
# Successfully built rhopca
# Installing collected packages: numcodecs, legacy-api-wrap, donfig, zarr, anndata, rhopca
# Successfully installed anndata-0.12.10 donfig-0.8.1.post1 legacy-api-wrap-1.5 numcodecs-0.16.5 rhopca-1.0.0 zarr-3.1.6

# %%
from pathlib import Path
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from skfda.datasets import fetch_growth

# repo_root = Path.cwd().resolve()
# if not (repo_root / "src").exists():
#     repo_root = repo_root.parent
# sys.path.insert(0, str(repo_root / "src"))

from rhopca.methods import functionalRhoPCA

# %%
# --- Load dataset ---
dataset = fetch_growth()
fd = dataset["data"]
y = np.array(dataset["target"])

boys_mask = y == 0
girls_mask = y == 1

boys_fd = fd[boys_mask]
girls_fd = fd[girls_mask]

ages = np.asarray(fd.grid_points[0], dtype=float)
heights = np.asarray(fd.data_matrix[..., 0], dtype=float)

n_subjects = heights.shape[0]
subject_ids = np.arange(n_subjects)
sex_labels = np.where(y == 0, "boy", "girl")

growth_df = pd.DataFrame(
    {
        "child_id": np.repeat(subject_ids, len(ages)),
        "age": np.tile(ages, n_subjects),
        "height": heights.reshape(-1),
        "sex": np.repeat(sex_labels, len(ages)),
    }
)

growth_df.head()
# Out:
#    child_id   age  height  sex
# 0         0  1.00    81.3  boy
# 1         0  1.25    84.2  boy
# 2         0  1.50    86.4  boy
# 3         0  1.75    88.9  boy
# 4         0  2.00    91.4  boy

# %%
growth_df.groupby("sex")["child_id"].nunique()
# Out:
# sex
# boy     39
# girl    54
# Name: child_id, dtype: int64

# %%
mdl = functionalRhoPCA(
    growth_df,
    contrast_column="sex",
    target="boy",
    background="girl",
    observation="child_id",
    time="age",
    gene="height",
    basis="bspline",
    num_basis_functions=7,
    n_components=7,
)

mdl.fit()
mdl.eigvals
# Out:
# array([31.42245674,  2.11680709,  1.44470081,  1.057268  ,  0.91377541,
#         0.38573437,  0.17841947])

# %%
observed_time = np.linspace(
    growth_df["age"].min(),
    growth_df["age"].max(),
    200,
    endpoint=True,
)

mdl.plot(plot_type="eigenfunction", components=1, time_values=observed_time)
mdl.plot(plot_type="eigenfunction", components=2, time_values=observed_time)

# %%
mdl.plot(plot_type="scatter", components=(1, 2))
